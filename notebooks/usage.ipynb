# %%
import shutil
import glob
import btcolour.classify
from btcolour.fit import *
from btcolour.classify import *
import os.path

# %%
glob.glob("/home/euan/Documents/btcolour/training_data/1/cam_id"+'/*.np')

test = ["/home/euan/Documents/colour_fitting/Leon_data/21-06-2024/leon_bee_photos_3rdMarch2023/session/1/02D53783700/photo_object_02D53783700_20230303_15_24_41.110852_15m_trying_0189.np",
        "/home/euan/Documents/colour_fitting/Leon_data/21-06-2024/leon_bee_photos_3rdMarch2023/session/1/02D53783700/photo_object_02D49670796_20230303_16_12_19.443318_Newfocus_10m_0183.np",
        "/home/euan/Documents/colour_fitting/Leon_data/21-06-2024/leon_bee_photos_3rdMarch2023/session/1/02D53783700/photo_object_02D49670796_20230303_16_12_34.504076_Newfocus_10m_0193.np",
        "/home/euan/Documents/colour_fitting/Leon_data/21-06-2024/leon_bee_photos_3rdMarch2023/session/1/02D53783700/photo_object_02D49670796_20230303_16_13_31.736117_Newfocus_10m_0231.np",
        "/home/euan/Documents/colour_fitting/Leon_data/21-06-2024/leon_bee_photos_3rdMarch2023/session/1/02D53783700/photo_object_02D49670796_20230303_16_15_08.965715_Newfocus_7m5_0273.np",
        "/home/euan/Documents/colour_fitting/Leon_data/21-06-2024/leon_bee_photos_3rdMarch2023/session/1/02D53783700/photo_object_02D53783700_20230303_15_19_20.821979_15m_trying_0073.np",
        "/home/euan/Documents/colour_fitting/Leon_data/21-06-2024/leon_bee_photos_3rdMarch2023/session/1/02D53783700/photo_object_02D53783700_20230303_15_28_56.803698_20m_trying_0259.np"]


parents = "/home/euan/Documents/btcolour/training_data/test_data/a/b/c"
for f in test:
    new = os.path.join(parents, os.path.split(f)[1])
    shutil.copy(f,new)

# %%
parents = "/home/euan/Documents/btcolour/training_data/a/b/1/cam_id"
new_files = []
'''
training =["/home/euan/Documents/colour_fitting/Leon_data/21-06-2024/leon_bee_photos_3rdMarch2023/training_data/1/cam_id/photo_object_02D53783700_20230303_16_12_07.375926_Newfocus_10m_0175.np",
           "/home/euan/Documents/colour_fitting/Leon_data/21-06-2024/leon_bee_photos_3rdMarch2023/training_data/1/cam_id/photo_object_02D53783700_20230303_15_24_35.085928_15m_trying_0185.np",
           "/home/euan/Documents/colour_fitting/Leon_data/21-06-2024/leon_bee_photos_3rdMarch2023/training_data/1/cam_id/photo_object_02D53783700_20230303_16_13_40.783171_Newfocus_10m_0237.np",
           "/home/euan/Documents/colour_fitting/Leon_data/21-06-2024/leon_bee_photos_3rdMarch2023/training_data/1/cam_id/photo_object_02D53783700_20230303_16_14_44.865582_Newfocus_7m5_0257.np",
           "/home/euan/Documents/colour_fitting/Leon_data/21-06-2024/leon_bee_photos_3rdMarch2023/training_data/1/cam_id/photo_object_02D53783700_20230303_16_11_10.900043_Newfocus_15m_0145.np",
           "/home/euan/Documents/colour_fitting/Leon_data/21-06-2024/leon_bee_photos_3rdMarch2023/training_data/1/cam_id/photo_object_02D53783700_20230303_15_55_48.760096_Newfocus_25m_0017.np",
            "/home/euan/Documents/colour_fitting/Leon_data/21-06-2024/leon_bee_photos_3rdMarch2023/training_data/1/cam_id/photo_object_02D53783700_20230303_15_29_20.901272_20m_trying_0275.np",
            "/home/euan/Documents/colour_fitting/Leon_data/21-06-2024/leon_bee_photos_3rdMarch2023/training_data/1/cam_id/photo_object_02D53783700_20230303_16_11_52.325032_Newfocus_10m_0165.np",
            "/home/euan/Documents/colour_fitting/Leon_data/21-06-2024/leon_bee_photos_3rdMarch2023/training_data/1/cam_id/photo_object_02D53783700_20230303_16_13_07.634861_Newfocus_10m_0215.np"]
'''
training = glob.glob(parents+'/*.np')



farthest = [23,1,38,28,39,32,34,5,19,12]

guesses, tag_indexes = extract_tags_from(training)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 21
#      18 farthest = [23,1,38,28,39,32,34,5,19,12]
#      20 guesses, tag_indexes = extract_tags_from(training)
# ---> 21 test_g, test_is = extract_tags_from(test)
#
# File ~/Documents/btcolour/btcolour/classify.py:67, in extract_tags_from(image_list, function, show, show_rgb, idx_to_see)
#      65 image_indexes = []
#      66 image_guesses = []
# ---> 67 img_raw, tag_list = btcolour.fit.image_loader(file)
#      68 tags = btcolour.fit.get_tags(img_raw,tag_list,buffer=7)
#      70 for i, tag in enumerate(tags):
#
# File ~/Documents/btcolour/btcolour/fit.py:118, in image_loader(file_path)
#     115 with open(img_path,'rb') as pick:
#     116     image_arr = np.array(pk.load(pick)['img'])
# --> 118 with open(file_path,'r') as tgs:
#     119     tag_json = json.load(tgs)
#     120 tags = []
#
# ...

# %%
test_parents = "/home/euan/Documents/btcolour/training_data/test_data/a/b/c"
testing = glob.glob(test_parents+'/*.np')
test_guesses, test_i  = extract_tags_from(testing)

# %%
farthest = [ 1,  5, 12, 19, 23, 28, 32, 37, 38, 39]
farthest
colours = ["yellow","orange","blue","greyblue","white","green","purple","red","skin","pink"]

# %%
def farthest_tags(means, k):
    remaining_points = means[:]
    solution_set = []
    solution_set.append(remaining_points.pop(\
        np.random.randint(0, len(remaining_points) - 1)))
    
    for _ in range(k-1):
        distances = [dist(p, solution_set[0]) for p in remaining_points]
        for i, p in enumerate(remaining_points):
            for j, s in enumerate(solution_set):
                distances[i] = max(distances[i], dist(p, s))
        solution_set.append(remaining_points.pop(distances.index(max(distances))))
    return solution_set

def dist(p1,p2):
    return np.linalg.norm(p2-p2)

# %%
def return_indexes(means,points):
    return [np.where(means == i)[0][0] for i in points]

# %%
# %matplotlib qt
args, std, means = best_tag_groups(guesses,tag_indexes)

farthest =  [1,  5, 12, 19, 23, 28, 32, 37, 38, 39]

means = np.array(means)
print(args)

fig = plt.figure(figsize=(8,8))
ax = plt.axes(projection="3d")
ax.scatter(means[:,0],means[:,1],means[:,2])
for f in farthest:
    ax.scatter(means[f,0],means[f,1],means[f,2],color="r",s=150)
#ax.scatter(farthest[:,0],farthest[:,1],farthest[:,2],color='r',s=100)
for i, (x,y,z) in enumerate(means):
    ax.text(x,y,z,i)
# Out:
# [24 22 20 23 36 13 38  1 28 18 35 19  0 21 14 17 11 16 34  8  6 32 39  3
#   4 15 30  9 10 25 27 33 31 26  5 29  7  2 37 12]

# %%
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
farthest = [ 1, 12, 19, 28, 32, 37 ,23, 38, 39, 5]
cut_gs, tag_ids, rgbs, y_labels = ext_indexes(guesses,tag_indexes,farthest)
test_gs, test_ids, test_rgbs, test_labels = ext_indexes(test_guesses,test_i, farthest)
k=7

k_neighbours = KNeighborsClassifier(n_neighbors=k)
print(rgbs[0])
k_neighbours.fit(rgbs, y_labels)
# Out:
# [0.37860273 0.41996176 0.20143551]
# KNeighborsClassifier(n_neighbors=7)

# %%
preds = []
for rgb, i in zip(test_rgbs,test_labels):
    pred_neighbour = k_neighbours.predict([rgb])
    print("\nActual: ", i)
    print("Predicted (neighbour): ", pred_neighbour)
# Out:
# Actual:  5
# Predicted (neighbour):  [23]
#
# Actual:  12
# Predicted (neighbour):  [23]
#
# Actual:  28
# Predicted (neighbour):  [19]
#
# Actual:  32
# Predicted (neighbour):  [12]
#
# Actual:  38
# Predicted (neighbour):  [23]
#
# Actual:  39
# Predicted (neighbour):  [23]
#
# Actual:  1
# Predicted (neighbour):  [1]
#
# Actual:  5
# Predicted (neighbour):  [28]
#
# Actual:  12
# Predicted (neighbour):  [12]
#
# Actual:  19
# Predicted (neighbour):  [19]
#
# Actual:  23
# Predicted (neighbour):  [23]
#
# Actual:  28
# Predicted (neighbour):  [1]
#
# Actual:  32
# Predicted (neighbour):  [32]
#
# Actual:  37
# Predicted (neighbour):  [37]
#
# Actual:  38
# Predicted (neighbour):  [5]
#
# Actual:  39
# Predicted (neighbour):  [12]
#
# Actual:  1
# Predicted (neighbour):  [23]
#
# Actual:  5
# Predicted (neighbour):  [12]
#
# Actual:  12
# Predicted (neighbour):  [23]
#
# Actual:  28
# Predicted (neighbour):  [23]
#
# Actual:  37
# Predicted (neighbour):  [23]
#
# Actual:  38
# ...

# %%
all_cols = np.meshgrid(np.arange(0,256,16),np.arange(0,256,16),np.arange(0,256,16))
all_cols = np.c_[all_cols[0].flatten(),all_cols[1].flatten(),all_cols[2].flatten()]

all_cols_n = all_cols / 255
all_cols_n
# Out:
# array([[0.        , 0.        , 0.        ],
#        [0.        , 0.        , 0.0627451 ],
#        [0.        , 0.        , 0.1254902 ],
#        ...,
#        [0.94117647, 0.94117647, 0.81568627],
#        [0.94117647, 0.94117647, 0.87843137],
#        [0.94117647, 0.94117647, 0.94117647]])

# %%
# %matplotlib qt
plt.ion()
fig = plt.figure(figsize=(7,7))
ax = plt.axes(projection="3d")
ax.scatter(all_cols[:,0],all_cols[:,1],all_cols[:,2],c=all_cols_n)

# %%
cut_guesses, cut_tag_indexes, rgbs = ext_indexes(guesses, tag_indexes, [27,32,22,39,9,36])
plot_guesses(guesses,tag_indexes)
#cluster(guesses,tag_indexes,rgbs,7)

# %%
[33,28,5,17,1,36,6,39,27,2,19,35]
# Out:
# [33, 28, 5, 17, 1, 36, 6, 39, 27, 2, 19, 35]

# %%
good_images = ["/home/euan/Documents/colour_fitting/Leon_data/21-06-2024/leon_bee_photos_3rdMarch2023/session/1/02D53783700/photo_object_02D53783700_20230303_15_24_01.952105_15m_trying_0163.np",
               "/home/euan/Documents/colour_fitting/Leon_data/21-06-2024/leon_bee_photos_3rdMarch2023/session/1/02D53783700/photo_object_02D53783700_20230303_15_24_20.024497_15m_trying_0175.np"]

plot_fitted_colour(good_images)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 good_images = ["/home/euan/Documents/colour_fitting/Leon_data/21-06-2024/leon_bee_photos_3rdMarch2023/session/1/02D53783700/photo_object_02D53783700_20230303_15_24_01.952105_15m_trying_0163.np",
#       2                "/home/euan/Documents/colour_fitting/Leon_data/21-06-2024/leon_bee_photos_3rdMarch2023/session/1/02D53783700/photo_object_02D53783700_20230303_15_24_20.024497_15m_trying_0175.np"]
# ----> 4 plot_fitted_colour(good_images)
#
# NameError: name 'plot_fitted_colour' is not defined
